# %%
library(ggplot2)
library(readr)


netflix_data <- read_csv("C://Users//Oremoxie//netflix-data-visualization//Netflix_shows_movies.csv")


ggplot(netflix_data, aes(x = rating)) +
      geom_bar(fill = 'skyblue', color = 'black') +
       theme_minimal() +
       labs(title = 'Distribution of Ratings in Netdlix Titles', x = 'Rating', y = 'Count') + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# Parsed with column specification:
# cols(
#   show_id = col_double(),
#   type = col_character(),
#   title = col_character(),
#   director = col_character(),
#   cast = col_character(),
#   country = col_character(),
#   date_added = col_character(),
#   release_year = col_double(),
#   rating = col_character(),
#   duration = col_character(),
#   listed_in = col_character(),
#   description = col_character()
# )
# plot without title
